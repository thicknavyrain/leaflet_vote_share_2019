# %%
import json
import os

def is_valid_json(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            json.load(file)
        return True
    except json.JSONDecodeError:
        return False

def fix_json_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    # Check and remove the problematic lines if they exist
    if lines[0].strip() == '```json':
        lines = lines[1:]  # Remove the first line
    if lines[-1].strip() == '```':
        lines = lines[:-1]  # Remove the last line

    # Try to join back the lines and parse as JSON
    try:
        json_data = json.loads(''.join(lines))
        # If successful, write back the corrected JSON
        with open(file_path, 'w', encoding='utf-8') as file:
            json.dump(json_data, file, indent=4)
        print(f"Fixed and saved valid JSON to {file_path}")
    except json.JSONDecodeError as e:
        print(f"Error fixing {file_path}: {e}")

def process_directory(directory_path):
    for filename in os.listdir(directory_path):
        if filename.endswith('.json'):
            file_path = os.path.join(directory_path, filename)
            if not is_valid_json(file_path):
                print(f"Invalid JSON detected: {filename}, attempting to fix...")
                fix_json_file(file_path)
            else:
                print(f"{filename} is a valid JSON file.")

# Replace 'your_directory_path' with the path to your directory containing JSON files
directory_path = 'leaflet_jsons_2017_2019'
process_directory(directory_path)
# Out:
# 28267.json is a valid JSON file.
# 30677.json is a valid JSON file.
# 29684.json is a valid JSON file.
# 33345.json is a valid JSON file.
# 33130.json is a valid JSON file.
# 32143.json is a valid JSON file.
# 31111.json is a valid JSON file.
# 32080.json is a valid JSON file.
# 38845.json is a valid JSON file.
# 31465.json is a valid JSON file.
# 31669.json is a valid JSON file.
# 34237.json is a valid JSON file.
# 27279.json is a valid JSON file.
# 33856.json is a valid JSON file.
# 31244.json is a valid JSON file.
# 34095.json is a valid JSON file.
# 29746.json is a valid JSON file.
# 35533.json is a valid JSON file.
# 30202.json is a valid JSON file.
# 34802.json is a valid JSON file.
# 32532.json is a valid JSON file.
# 26994.json is a valid JSON file.
# 29398.json is a valid JSON file.
# 33724.json is a valid JSON file.
# 29085.json is a valid JSON file.
# 33051.json is a valid JSON file.
# 27946.json is a valid JSON file.
# 29128.json is a valid JSON file.
# 38775.json is a valid JSON file.
# 34983.json is a valid JSON file.
# 29155.json is a valid JSON file.
# 34526.json is a valid JSON file.
# 27486.json is a valid JSON file.
# 38743.json is a valid JSON file.
# 34416.json is a valid JSON file.
# 31737.json is a valid JSON file.
# 34382.json is a valid JSON file.
# 29668.json is a valid JSON file.
# 27056.json is a valid JSON file.
# 32737.json is a valid JSON file.
# 33357.json is a valid JSON file.
# 29436.json is a valid JSON file.
# 26610.json is a valid JSON file.
# 32599.json is a valid JSON file.
# 34987.json is a valid JSON file.
# 29454.json is a valid JSON file.
# 38690.json is a valid JSON file.
# 27270.json is a valid JSON file.
# 30419.json is a valid JSON file.
# 33685.json is a valid JSON file.
# 30937.json is a valid JSON file.
# 29777.json is a valid JSON file.
# 27682.json is a valid JSON file.
# 28207.json is a valid JSON file.
# 27574.json is a valid JSON file.
# 28722.json is a valid JSON file.
# 32463.json is a valid JSON file.
# 28407.json is a valid JSON file.
# 34683.json is a valid JSON file.
# 30829.json is a valid JSON file.
# 28875.json is a valid JSON file.
# 30764.json is a valid JSON file.
# 28626.json is a valid JSON file.
# 34553.json is a valid JSON file.
# 29263.json is a valid JSON file.
# 29273.json is a valid JSON file.
# 2796.json is a valid JSON file.
# 33363.json is a valid JSON file.
# 33155.json is a valid JSON file.
# 31932.json is a valid JSON file.
# 34510.json is a valid JSON file.
# 30118.json is a valid JSON file.
# 34567.json is a valid JSON file.
# 29080.json is a valid JSON file.
# 30290.json is a valid JSON file.
# 26591.json is a valid JSON file.
# 35592.json is a valid JSON file.
# 32859.json is a valid JSON file.
# 33862.json is a valid JSON file.
# 28734.json is a valid JSON file.
# 26950.json is a valid JSON file.
# 32109.json is a valid JSON file.
# 27841.json is a valid JSON file.
# 33164.json is a valid JSON file.
# 27605.json is a valid JSON file.
# 30091.json is a valid JSON file.
# 34310.json is a valid JSON file.
# 35648.json is a valid JSON file.
# 28339.json is a valid JSON file.
# 26777.json is a valid JSON file.
# 30876.json is a valid JSON file.
# 28659.json is a valid JSON file.
# 32606.json is a valid JSON file.
# 27530.json is a valid JSON file.
# 28559.json is a valid JSON file.
# 29439.json is a valid JSON file.
# 34053.json is a valid JSON file.
# 33372.json is a valid JSON file.
# 38926.json is a valid JSON file.
# 32748.json is a valid JSON file.
# 30345.json is a valid JSON file.
# 32473.json is a valid JSON file.
# 34182.json is a valid JSON file.
# 36820.json is a valid JSON file.
# 26561.json is a valid JSON file.
# 34915.json is a valid JSON file.
# 34083.json is a valid JSON file.
# 34449.json is a valid JSON file.
# 30194.json is a valid JSON file.
# 32529.json is a valid JSON file.
# 28166.json is a valid JSON file.
# 30613.json is a valid JSON file.
# 32231.json is a valid JSON file.
# 26517.json is a valid JSON file.
# 26613.json is a valid JSON file.
# 38763.json is a valid JSON file.
# 27331.json is a valid JSON file.
# 31302.json is a valid JSON file.
# 30779.json is a valid JSON file.
# 31428.json is a valid JSON file.
# 30339.json is a valid JSON file.
# 28177.json is a valid JSON file.
# 30220.json is a valid JSON file.
# 27191.json is a valid JSON file.
# 33646.json is a valid JSON file.
# 28023.json is a valid JSON file.
# 28656.json is a valid JSON file.
# 34029.json is a valid JSON file.
# 30711.json is a valid JSON file.
# 29188.json is a valid JSON file.
# 28311.json is a valid JSON file.
# 26935.json is a valid JSON file.
# 28591.json is a valid JSON file.
# 27787.json is a valid JSON file.
# 29118.json is a valid JSON file.
# 33633.json is a valid JSON file.
# 34500.json is a valid JSON file.
# 28050.json is a valid JSON file.
# 29098.json is a valid JSON file.
# 38921.json is a valid JSON file.
# 38799.json is a valid JSON file.
# 27245.json is a valid JSON file.
# 34958.json is a valid JSON file.
# 32581.json is a valid JSON file.
# 27257.json is a valid JSON file.
# 33463.json is a valid JSON file.
# 34976.json is a valid JSON file.
# 33598.json is a valid JSON file.
# 30726.json is a valid JSON file.
# 27282.json is a valid JSON file.
# 34540.json is a valid JSON file.
# 34277.json is a valid JSON file.
# 32237.json is a valid JSON file.
# 32639.json is a valid JSON file.
# 34071.json is a valid JSON file.
# 33639.json is a valid JSON file.
# 26909.json is a valid JSON file.
# 27426.json is a valid JSON file.
# 30596.json is a valid JSON file.
# 27432.json is a valid JSON file.
# 33692.json is a valid JSON file.
# 34760.json is a valid JSON file.
# 34724.json is a valid JSON file.
# 29229.json is a valid JSON file.
# 31320.json is a valid JSON file.
# 28984.json is a valid JSON file.
# 38702.json is a valid JSON file.
# 31634.json is a valid JSON file.
# 32844.json is a valid JSON file.
# 30397.json is a valid JSON file.
# 30072.json is a valid JSON file.
# 29170.json is a valid JSON file.
# 32901.json is a valid JSON file.
# 34845.json is a valid JSON file.
# 29173.json is a valid JSON file.
# 34443.json is a valid JSON file.
# 28302.json is a valid JSON file.
# 27650.json is a valid JSON file.
# 36870.json is a valid JSON file.
# 34905.json is a valid JSON file.
# 27422.json is a valid JSON file.
# 34271.json is a valid JSON file.
# 28990.json is a valid JSON file.
# 27364.json is a valid JSON file.
# 27508.json is a valid JSON file.
# 28836.json is a valid JSON file.
# 26975.json is a valid JSON file.
# 28186.json is a valid JSON file.
# 30546.json is a valid JSON file.
# 33148.json is a valid JSON file.
# 28941.json is a valid JSON file.
# 32185.json is a valid JSON file.
# 33538.json is a valid JSON file.
# 34731.json is a valid JSON file.
# 28569.json is a valid JSON file.
# 28213.json is a valid JSON file.
# 29317.json is a valid JSON file.
# 30857.json is a valid JSON file.
# 34671.json is a valid JSON file.
# 32535.json is a valid JSON file.
# 30932.json is a valid JSON file.
# 35604.json is a valid JSON file.
# 36829.json is a valid JSON file.
# 31129.json is a valid JSON file.
# 30757.json is a valid JSON file.
# 34307.json is a valid JSON file.
# 28174.json is a valid JSON file.
# 30017.json is a valid JSON file.
# 32850.json is a valid JSON file.
# 32876.json is a valid JSON file.
# 30109.json is a valid JSON file.
# 30348.json is a valid JSON file.
# 28782.json is a valid JSON file.
# 28705.json is a valid JSON file.
# 28878.json is a valid JSON file.
# 29245.json is a valid JSON file.
# 27514.json is a valid JSON file.
# 30790.json is a valid JSON file.
# 34504.json is a valid JSON file.
# 29225.json is a valid JSON file.
# 29241.json is a valid JSON file.
# 33311.json is a valid JSON file.
# 26659.json is a valid JSON file.
# 28975.json is a valid JSON file.
# 29646.json is a valid JSON file.
# 28405.json is a valid JSON file.
# 27239.json is a valid JSON file.
# 32343.json is a valid JSON file.
# 26751.json is a valid JSON file.
# 31514.json is a valid JSON file.
# 34280.json is a valid JSON file.
# 33577.json is a valid JSON file.
# 31927.json is a valid JSON file.
# 33678.json is a valid JSON file.
# 35561.json is a valid JSON file.
# 33279.json is a valid JSON file.
# 34827.json is a valid JSON file.
# 27384.json is a valid JSON file.
# 32746.json is a valid JSON file.
# 34650.json is a valid JSON file.
# 38932.json is a valid JSON file.
# 28083.json is a valid JSON file.
# 28441.json is a valid JSON file.
# 30460.json is a valid JSON file.
# 27027.json is a valid JSON file.
# 26555.json is a valid JSON file.
# 27202.json is a valid JSON file.
# 30863.json is a valid JSON file.
# 27539.json is a valid JSON file.
# 33666.json is a valid JSON file.
# 28881.json is a valid JSON file.
# 29629.json is a valid JSON file.
# 30162.json is a valid JSON file.
# 26552.json is a valid JSON file.
# Invalid JSON detected: 33811.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/33811.json: Expecting ',' delimiter: line 28 column 7 (char 1854)
# 30541.json is a valid JSON file.
# 29253.json is a valid JSON file.
# 26588.json is a valid JSON file.
# 27370.json is a valid JSON file.
# 32319.json is a valid JSON file.
# 32836.json is a valid JSON file.
# 30649.json is a valid JSON file.
# 28603.json is a valid JSON file.
# 28904.json is a valid JSON file.
# 30405.json is a valid JSON file.
# 26616.json is a valid JSON file.
# 29013.json is a valid JSON file.
# 35532.json is a valid JSON file.
# 34608.json is a valid JSON file.
# 32922.json is a valid JSON file.
# 30782.json is a valid JSON file.
# 30287.json is a valid JSON file.
# 29676.json is a valid JSON file.
# 32170.json is a valid JSON file.
# 33550.json is a valid JSON file.
# 34721.json is a valid JSON file.
# 29550.json is a valid JSON file.
# 26628.json is a valid JSON file.
# 27943.json is a valid JSON file.
# 33982.json is a valid JSON file.
# 28195.json is a valid JSON file.
# 27394.json is a valid JSON file.
# 30681.json is a valid JSON file.
# 28618.json is a valid JSON file.
# 27162.json is a valid JSON file.
# 33033.json is a valid JSON file.
# 31108.json is a valid JSON file.
# 30484.json is a valid JSON file.
# 29844.json is a valid JSON file.
# 30824.json is a valid JSON file.
# 34328.json is a valid JSON file.
# 30230.json is a valid JSON file.
# 28431.json is a valid JSON file.
# Invalid JSON detected: 29027.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/29027.json: Invalid control character at: line 86 column 218 (char 4482)
# 34400.json is a valid JSON file.
# 34740.json is a valid JSON file.
# 32958.json is a valid JSON file.
# 34431.json is a valid JSON file.
# 31954.json is a valid JSON file.
# 29199.json is a valid JSON file.
# 30062.json is a valid JSON file.
# 38830.json is a valid JSON file.
# Invalid JSON detected: 33036.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/33036.json: Expecting ',' delimiter: line 131 column 75 (char 4487)
# 32224.json is a valid JSON file.
# 34641.json is a valid JSON file.
# 34479.json is a valid JSON file.
# 29956.json is a valid JSON file.
# 30227.json is a valid JSON file.
# 31407.json is a valid JSON file.
# 31923.json is a valid JSON file.
# 27321.json is a valid JSON file.
# Invalid JSON detected: 34240.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/34240.json: Invalid control character at: line 149 column 126 (char 5766)
# 30860.json is a valid JSON file.
# 35003.json is a valid JSON file.
# 29757.json is a valid JSON file.
# 28463.json is a valid JSON file.
# 29643.json is a valid JSON file.
# 27973.json is a valid JSON file.
# 27093.json is a valid JSON file.
# 28680.json is a valid JSON file.
# 28793.json is a valid JSON file.
# 32732.json is a valid JSON file.
# 28148.json is a valid JSON file.
# 34775.json is a valid JSON file.
# 31642.json is a valid JSON file.
# 30336.json is a valid JSON file.
# 29032.json is a valid JSON file.
# 32636.json is a valid JSON file.
# 26894.json is a valid JSON file.
# 34713.json is a valid JSON file.
# 28444.json is a valid JSON file.
# 31065.json is a valid JSON file.
# 31690.json is a valid JSON file.
# 27104.json is a valid JSON file.
# 31260.json is a valid JSON file.
# 38842.json is a valid JSON file.
# 29774.json is a valid JSON file.
# 30156.json is a valid JSON file.
# 34840.json is a valid JSON file.
# 34468.json is a valid JSON file.
# 29602.json is a valid JSON file.
# 32664.json is a valid JSON file.
# 33651.json is a valid JSON file.
# 30312.json is a valid JSON file.
# 27435.json is a valid JSON file.
# 29890.json is a valid JSON file.
# 26709.json is a valid JSON file.
# 27952.json is a valid JSON file.
# 26619.json is a valid JSON file.
# 30544.json is a valid JSON file.
# 29414.json is a valid JSON file.
# 30636.json is a valid JSON file.
# 27543.json is a valid JSON file.
# 30369.json is a valid JSON file.
# 33661.json is a valid JSON file.
# 31295.json is a valid JSON file.
# 30284.json is a valid JSON file.
# 30610.json is a valid JSON file.
# 32507.json is a valid JSON file.
# 28129.json is a valid JSON file.
# 32032.json is a valid JSON file.
# 32148.json is a valid JSON file.
# 31622.json is a valid JSON file.
# 34274.json is a valid JSON file.
# 28995.json is a valid JSON file.
# 27167.json is a valid JSON file.
# 26938.json is a valid JSON file.
# 32332.json is a valid JSON file.
# 38655.json is a valid JSON file.
# 29419.json is a valid JSON file.
# 32281.json is a valid JSON file.
# 34788.json is a valid JSON file.
# 33104.json is a valid JSON file.
# 29635.json is a valid JSON file.
# 28067.json is a valid JSON file.
# 34626.json is a valid JSON file.
# 33850.json is a valid JSON file.
# 28683.json is a valid JSON file.
# 29408.json is a valid JSON file.
# 31587.json is a valid JSON file.
# 26714.json is a valid JSON file.
# 30741.json is a valid JSON file.
# 36775.json is a valid JSON file.
# 29279.json is a valid JSON file.
# 33101.json is a valid JSON file.
# 38966.json is a valid JSON file.
# 31106.json is a valid JSON file.
# 30114.json is a valid JSON file.
# 29600.json is a valid JSON file.
# 32588.json is a valid JSON file.
# 27854.json is a valid JSON file.
# 34452.json is a valid JSON file.
# 30622.json is a valid JSON file.
# 27717.json is a valid JSON file.
# 32862.json is a valid JSON file.
# 38890.json is a valid JSON file.
# 28076.json is a valid JSON file.
# 33893.json is a valid JSON file.
# 31265.json is a valid JSON file.
# 27734.json is a valid JSON file.
# 27361.json is a valid JSON file.
# 30366.json is a valid JSON file.
# 31044.json is a valid JSON file.
# 33239.json is a valid JSON file.
# 29557.json is a valid JSON file.
# 29369.json is a valid JSON file.
# 34067.json is a valid JSON file.
# 28358.json is a valid JSON file.
# 34446.json is a valid JSON file.
# 30241.json is a valid JSON file.
# 32629.json is a valid JSON file.
# 34298.json is a valid JSON file.
# 27610.json is a valid JSON file.
# 34565.json is a valid JSON file.
# 30598.json is a valid JSON file.
# 34653.json is a valid JSON file.
# 33396.json is a valid JSON file.
# 33209.json is a valid JSON file.
# 27471.json is a valid JSON file.
# 27251.json is a valid JSON file.
# 29852.json is a valid JSON file.
# 26739.json is a valid JSON file.
# 31147.json is a valid JSON file.
# 31282.json is a valid JSON file.
# 32549.json is a valid JSON file.
# 30451.json is a valid JSON file.
# 35597.json is a valid JSON file.
# 30082.json is a valid JSON file.
# 32028.json is a valid JSON file.
# 34342.json is a valid JSON file.
# 30293.json is a valid JSON file.
# 38717.json is a valid JSON file.
# 2867.json is a valid JSON file.
# 29935.json is a valid JSON file.
# 29834.json is a valid JSON file.
# 31653.json is a valid JSON file.
# 31679.json is a valid JSON file.
# 26780.json is a valid JSON file.
# 34148.json is a valid JSON file.
# 27194.json is a valid JSON file.
# 28527.json is a valid JSON file.
# 32676.json is a valid JSON file.
# 27290.json is a valid JSON file.
# 33479.json is a valid JSON file.
# 34050.json is a valid JSON file.
# 38752.json is a valid JSON file.
# 27720.json is a valid JSON file.
# 30508.json is a valid JSON file.
# 34631.json is a valid JSON file.
# 33222.json is a valid JSON file.
# 32322.json is a valid JSON file.
# 26694.json is a valid JSON file.
# 33124.json is a valid JSON file.
# 33608.json is a valid JSON file.
# 34678.json is a valid JSON file.
# 30492.json is a valid JSON file.
# 34570.json is a valid JSON file.
# 35645.json is a valid JSON file.
# 33993.json is a valid JSON file.
# 33529.json is a valid JSON file.
# 38836.json is a valid JSON file.
# 28020.json is a valid JSON file.
# 38778.json is a valid JSON file.
# 31188.json is a valid JSON file.
# 32275.json is a valid JSON file.
# 26771.json is a valid JSON file.
# 29016.json is a valid JSON file.
# 33630.json is a valid JSON file.
# 26537.json is a valid JSON file.
# 29538.json is a valid JSON file.
# 30960.json is a valid JSON file.
# 38896.json is a valid JSON file.
# 27578.json is a valid JSON file.
# 33009.json is a valid JSON file.
# 26969.json is a valid JSON file.
# 27490.json is a valid JSON file.
# 27367.json is a valid JSON file.
# 30413.json is a valid JSON file.
# 30144.json is a valid JSON file.
# 33602.json is a valid JSON file.
# 32219.json is a valid JSON file.
# 33657.json is a valid JSON file.
# 31083.json is a valid JSON file.
# 27913.json is a valid JSON file.
# 29211.json is a valid JSON file.
# 29545.json is a valid JSON file.
# 27934.json is a valid JSON file.
# 31219.json is a valid JSON file.
# 33158.json is a valid JSON file.
# 27564.json is a valid JSON file.
# 30223.json is a valid JSON file.
# 34085.json is a valid JSON file.
# 29976.json is a valid JSON file.
# 31435.json is a valid JSON file.
# 35618.json is a valid JSON file.
# 2812.json is a valid JSON file.
# 32669.json is a valid JSON file.
# 35534.json is a valid JSON file.
# 33056.json is a valid JSON file.
# 28583.json is a valid JSON file.
# 34936.json is a valid JSON file.
# 31317.json is a valid JSON file.
# 32123.json is a valid JSON file.
# 28079.json is a valid JSON file.
# 29165.json is a valid JSON file.
# 26578.json is a valid JSON file.
# 27046.json is a valid JSON file.
# 34734.json is a valid JSON file.
# 2858.json is a valid JSON file.
# 33541.json is a valid JSON file.
# 38809.json is a valid JSON file.
# 28151.json is a valid JSON file.
# 33391.json is a valid JSON file.
# 30917.json is a valid JSON file.
# 28756.json is a valid JSON file.
# 33500.json is a valid JSON file.
# 26635.json is a valid JSON file.
# 33641.json is a valid JSON file.
# 38868.json is a valid JSON file.
# 30422.json is a valid JSON file.
# 33835.json is a valid JSON file.
# 33504.json is a valid JSON file.
# 31276.json is a valid JSON file.
# 34455.json is a valid JSON file.
# 33016.json is a valid JSON file.
# 26511.json is a valid JSON file.
# 33013.json is a valid JSON file.
# 35546.json is a valid JSON file.
# 29147.json is a valid JSON file.
# 31599.json is a valid JSON file.
# 29019.json is a valid JSON file.
# 34002.json is a valid JSON file.
# 31490.json is a valid JSON file.
# 29661.json is a valid JSON file.
# 27209.json is a valid JSON file.
# 34290.json is a valid JSON file.
# 30708.json is a valid JSON file.
# 28709.json is a valid JSON file.
# 34403.json is a valid JSON file.
# 32949.json is a valid JSON file.
# 34550.json is a valid JSON file.
# 27886.json is a valid JSON file.
# 27524.json is a valid JSON file.
# 30191.json is a valid JSON file.
# 27536.json is a valid JSON file.
# 28417.json is a valid JSON file.
# 26797.json is a valid JSON file.
# 35654.json is a valid JSON file.
# 33978.json is a valid JSON file.
# 27069.json is a valid JSON file.
# 26544.json is a valid JSON file.
# 30315.json is a valid JSON file.
# 29045.json is a valid JSON file.
# 32077.json is a valid JSON file.
# 27157.json is a valid JSON file.
# 28160.json is a valid JSON file.
# 34295.json is a valid JSON file.
# 28425.json is a valid JSON file.
# 31354.json is a valid JSON file.
# 30948.json is a valid JSON file.
# 32466.json is a valid JSON file.
# 30999.json is a valid JSON file.
# 38877.json is a valid JSON file.
# 27697.json is a valid JSON file.
# 34779.json is a valid JSON file.
# 32714.json is a valid JSON file.
# 34940.json is a valid JSON file.
# 30253.json is a valid JSON file.
# 29579.json is a valid JSON file.
# 38708.json is a valid JSON file.
# 33249.json is a valid JSON file.
# 27889.json is a valid JSON file.
# 32413.json is a valid JSON file.
# 28033.json is a valid JSON file.
# 33061.json is a valid JSON file.
# 27223.json is a valid JSON file.
# 33181.json is a valid JSON file.
# 28109.json is a valid JSON file.
# 34048.json is a valid JSON file.
# 34955.json is a valid JSON file.
# 28512.json is a valid JSON file.
# 33985.json is a valid JSON file.
# 33507.json is a valid JSON file.
# 34151.json is a valid JSON file.
# 30391.json is a valid JSON file.
# 34886.json is a valid JSON file.
# 31508.json is a valid JSON file.
# 38787.json is a valid JSON file.
# 39000.json is a valid JSON file.
# 27233.json is a valid JSON file.
# 26575.json is a valid JSON file.
# 28530.json is a valid JSON file.
# 31562.json is a valid JSON file.
# 34875.json is a valid JSON file.
# 34575.json is a valid JSON file.
# 29498.json is a valid JSON file.
# 29959.json is a valid JSON file.
# 34584.json is a valid JSON file.
# 34335.json is a valid JSON file.
# 32719.json is a valid JSON file.
# 29306.json is a valid JSON file.
# 34282.json is a valid JSON file.
# 32494.json is a valid JSON file.
# 31018.json is a valid JSON file.
# 34232.json is a valid JSON file.
# 34767.json is a valid JSON file.
# 30590.json is a valid JSON file.
# 29785.json is a valid JSON file.
# 27000.json is a valid JSON file.
# 34880.json is a valid JSON file.
# 38664.json is a valid JSON file.
# 28008.json is a valid JSON file.
# 27397.json is a valid JSON file.
# 30250.json is a valid JSON file.
# 32067.json is a valid JSON file.
# 29395.json is a valid JSON file.
# 32361.json is a valid JSON file.
# 29620.json is a valid JSON file.
# 34636.json is a valid JSON file.
# 29760.json is a valid JSON file.
# 28895.json is a valid JSON file.
# 30744.json is a valid JSON file.
# 28911.json is a valid JSON file.
# 33342.json is a valid JSON file.
# 29193.json is a valid JSON file.
# 28517.json is a valid JSON file.
# 33771.json is a valid JSON file.
# 28198.json is a valid JSON file.
# 33592.json is a valid JSON file.
# 30929.json is a valid JSON file.
# 27647.json is a valid JSON file.
# 31210.json is a valid JSON file.
# 29298.json is a valid JSON file.
# 33700.json is a valid JSON file.
# 32577.json is a valid JSON file.
# 38699.json is a valid JSON file.
# 27138.json is a valid JSON file.
# 28848.json is a valid JSON file.
# 29573.json is a valid JSON file.
# 30669.json is a valid JSON file.
# 31511.json is a valid JSON file.
# 32416.json is a valid JSON file.
# 30153.json is a valid JSON file.
# 33877.json is a valid JSON file.
# 28320.json is a valid JSON file.
# 28277.json is a valid JSON file.
# 34475.json is a valid JSON file.
# 33425.json is a valid JSON file.
# 27572.json is a valid JSON file.
# 31637.json is a valid JSON file.
# 30549.json is a valid JSON file.
# 33533.json is a valid JSON file.
# 38731.json is a valid JSON file.
# 29720.json is a valid JSON file.
# 34367.json is a valid JSON file.
# 34301.json is a valid JSON file.
# 34331.json is a valid JSON file.
# 29576.json is a valid JSON file.
# 31014.json is a valid JSON file.
# 32005.json is a valid JSON file.
# 34854.json is a valid JSON file.
# 27803.json is a valid JSON file.
# 26947.json is a valid JSON file.
# 28978.json is a valid JSON file.
# 26844.json is a valid JSON file.
# 30978.json is a valid JSON file.
# 26944.json is a valid JSON file.
# 38972.json is a valid JSON file.
# 33713.json is a valid JSON file.
# 30720.json is a valid JSON file.
# 27847.json is a valid JSON file.
# 27878.json is a valid JSON file.
# 30379.json is a valid JSON file.
# 31171.json is a valid JSON file.
# 30497.json is a valid JSON file.
# 32051.json is a valid JSON file.
# 31057.json is a valid JSON file.
# 31404.json is a valid JSON file.
# 38781.json is a valid JSON file.
# 30586.json is a valid JSON file.
# 33089.json is a valid JSON file.
# 32891.json is a valid JSON file.
# 38874.json is a valid JSON file.
# 34519.json is a valid JSON file.
# 28349.json is a valid JSON file.
# 38941.json is a valid JSON file.
# 26953.json is a valid JSON file.
# 34837.json is a valid JSON file.
# 26597.json is a valid JSON file.
# 29553.json is a valid JSON file.
# 30428.json is a valid JSON file.
# 32742.json is a valid JSON file.
# 26647.json is a valid JSON file.
# 33942.json is a valid JSON file.
# 38847.json is a valid JSON file.
# 27115.json is a valid JSON file.
# Invalid JSON detected: 34675.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/34675.json: Expecting ',' delimiter: line 25 column 5 (char 522)
# 32283.json is a valid JSON file.
# 27023.json is a valid JSON file.
# 29061.json is a valid JSON file.
# 33721.json is a valid JSON file.
# 28230.json is a valid JSON file.
# 29947.json is a valid JSON file.
# 32556.json is a valid JSON file.
# 33948.json is a valid JSON file.
# 29682.json is a valid JSON file.
# 27035.json is a valid JSON file.
# 29511.json is a valid JSON file.
# 34930.json is a valid JSON file.
# 32853.json is a valid JSON file.
# 30262.json is a valid JSON file.
# 29389.json is a valid JSON file.
# 27170.json is a valid JSON file.
# 31332.json is a valid JSON file.
# 29808.json is a valid JSON file.
# 38983.json is a valid JSON file.
# 29912.json is a valid JSON file.
# 28715.json is a valid JSON file.
# 29632.json is a valid JSON file.
# 29880.json is a valid JSON file.
# 28305.json is a valid JSON file.
# 27211.json is a valid JSON file.
# 33212.json is a valid JSON file.
# 30076.json is a valid JSON file.
# 29847.json is a valid JSON file.
# 33798.json is a valid JSON file.
# 30705.json is a valid JSON file.
# 29035.json is a valid JSON file.
# 32711.json is a valid JSON file.
# 26520.json is a valid JSON file.
# 26800.json is a valid JSON file.
# 33585.json is a valid JSON file.
# 32213.json is a valid JSON file.
# 34497.json is a valid JSON file.
# 27381.json is a valid JSON file.
# 28548.json is a valid JSON file.
# 30735.json is a valid JSON file.
# 28803.json is a valid JSON file.
# 33378.json is a valid JSON file.
# 32825.json is a valid JSON file.
# 33027.json is a valid JSON file.
# 29814.json is a valid JSON file.
# 32179.json is a valid JSON file.
# 28981.json is a valid JSON file.
# 34348.json is a valid JSON file.
# 34918.json is a valid JSON file.
# 28901.json is a valid JSON file.
# 2799.json is a valid JSON file.
# 33553.json is a valid JSON file.
# 33890.json is a valid JSON file.
# 29134.json is a valid JSON file.
# 29123.json is a valid JSON file.
# 28490.json is a valid JSON file.
# 26571.json is a valid JSON file.
# 28892.json is a valid JSON file.
# 26879.json is a valid JSON file.
# 30233.json is a valid JSON file.
# 30183.json is a valid JSON file.
# 29570.json is a valid JSON file.
# 32455.json is a valid JSON file.
# 26997.json is a valid JSON file.
# 27353.json is a valid JSON file.
# 30975.json is a valid JSON file.
# 38906.json is a valid JSON file.
# 31311.json is a valid JSON file.
# 31249.json is a valid JSON file.
# 27301.json is a valid JSON file.
# 28760.json is a valid JSON file.
# 30674.json is a valid JSON file.
# 30196.json is a valid JSON file.
# 30694.json is a valid JSON file.
# 30123.json is a valid JSON file.
# 31444.json is a valid JSON file.
# 31225.json is a valid JSON file.
# 32491.json is a valid JSON file.
# 30571.json is a valid JSON file.
# 28949.json is a valid JSON file.
# 35570.json is a valid JSON file.
# 32964.json is a valid JSON file.
# 29979.json is a valid JSON file.
# 27391.json is a valid JSON file.
# 26681.json is a valid JSON file.
# 27499.json is a valid JSON file.
# 34863.json is a valid JSON file.
# 32036.json is a valid JSON file.
# 30056.json is a valid JSON file.
# 34074.json is a valid JSON file.
# 31052.json is a valid JSON file.
# 28688.json is a valid JSON file.
# 30331.json is a valid JSON file.
# 31138.json is a valid JSON file.
# 29205.json is a valid JSON file.
# 33927.json is a valid JSON file.
# 34422.json is a valid JSON file.
# 34869.json is a valid JSON file.
# 33086.json is a valid JSON file.
# 33669.json is a valid JSON file.
# 38886.json is a valid JSON file.
# 27675.json is a valid JSON file.
# 29607.json is a valid JSON file.
# 33039.json is a valid JSON file.
# 29893.json is a valid JSON file.
# 31074.json is a valid JSON file.
# 29276.json is a valid JSON file.
# 34388.json is a valid JSON file.
# 27049.json is a valid JSON file.
# 30363.json is a valid JSON file.
# 34821.json is a valid JSON file.
# Invalid JSON detected: 28053.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/28053.json: Invalid control character at: line 66 column 168 (char 2806)
# 32489.json is a valid JSON file.
# 30208.json is a valid JSON file.
# 34662.json is a valid JSON file.
# 30776.json is a valid JSON file.
# 29338.json is a valid JSON file.
# 33093.json is a valid JSON file.
# 38696.json is a valid JSON file.
# 30265.json is a valid JSON file.
# 29269.json is a valid JSON file.
# 36537.json is a valid JSON file.
# 27767.json is a valid JSON file.
# 28449.json is a valid JSON file.
# 34208.json is a valid JSON file.
# 28251.json is a valid JSON file.
# 34716.json is a valid JSON file.
# 2823.json is a valid JSON file.
# 31474.json is a valid JSON file.
# 27134.json is a valid JSON file.
# 34012.json is a valid JSON file.
# 30317.json is a valid JSON file.
# 28800.json is a valid JSON file.
# 34262.json is a valid JSON file.
# 29999.json is a valid JSON file.
# 32545.json is a valid JSON file.
# 29182.json is a valid JSON file.
# 27984.json is a valid JSON file.
# 31155.json is a valid JSON file.
# 26567.json is a valid JSON file.
# 28378.json is a valid JSON file.
# 38883.json is a valid JSON file.
# 30407.json is a valid JSON file.
# 31438.json is a valid JSON file.
# 38901.json is a valid JSON file.
# 38734.json is a valid JSON file.
# 30214.json is a valid JSON file.
# 29314.json is a valid JSON file.
# 31273.json is a valid JSON file.
# 33820.json is a valid JSON file.
# 34125.json is a valid JSON file.
# 28639.json is a valid JSON file.
# 27481.json is a valid JSON file.
# 28777.json is a valid JSON file.
# 29766.json is a valid JSON file.
# 26774.json is a valid JSON file.
# 29450.json is a valid JSON file.
# 28929.json is a valid JSON file.
# 26984.json is a valid JSON file.
# 31517.json is a valid JSON file.
# 32984.json is a valid JSON file.
# 28958.json is a valid JSON file.
# 33782.json is a valid JSON file.
# 34581.json is a valid JSON file.
# 32438.json is a valid JSON file.
# 35621.json is a valid JSON file.
# 33999.json is a valid JSON file.
# 33571.json is a valid JSON file.
# 28123.json is a valid JSON file.
# 35578.json is a valid JSON file.
# 29713.json is a valid JSON file.
# 33514.json is a valid JSON file.
# 34304.json is a valid JSON file.
# 29649.json is a valid JSON file.
# 27761.json is a valid JSON file.
# 30431.json is a valid JSON file.
# 29754.json is a valid JSON file.
# 38948.json is a valid JSON file.
# 27003.json is a valid JSON file.
# 29250.json is a valid JSON file.
# 34362.json is a valid JSON file.
# 34629.json is a valid JSON file.
# 28786.json is a valid JSON file.
# 30403.json is a valid JSON file.
# 33272.json is a valid JSON file.
# 32814.json is a valid JSON file.
# 32423.json is a valid JSON file.
# Invalid JSON detected: 32783.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/32783.json: Expecting value: line 112 column 5 (char 3503)
# 27131.json is a valid JSON file.
# 30821.json is a valid JSON file.
# 30159.json is a valid JSON file.
# 27214.json is a valid JSON file.
# 34946.json is a valid JSON file.
# 27388.json is a valid JSON file.
# 33689.json is a valid JSON file.
# 33644.json is a valid JSON file.
# 30467.json is a valid JSON file.
# 32702.json is a valid JSON file.
# 32156.json is a valid JSON file.
# 30174.json is a valid JSON file.
# 31584.json is a valid JSON file.
# 27552.json is a valid JSON file.
# 32297.json is a valid JSON file.
# 29090.json is a valid JSON file.
# 29771.json is a valid JSON file.
# 29856.json is a valid JSON file.
# 28933.json is a valid JSON file.
# 33064.json is a valid JSON file.
# 31029.json is a valid JSON file.
# 27176.json is a valid JSON file.
# 32879.json is a valid JSON file.
# 30320.json is a valid JSON file.
# 32970.json is a valid JSON file.
# 34727.json is a valid JSON file.
# 30601.json is a valid JSON file.
# 33672.json is a valid JSON file.
# 29652.json is a valid JSON file.
# 32324.json is a valid JSON file.
# 29106.json is a valid JSON file.
# 32666.json is a valid JSON file.
# 27411.json is a valid JSON file.
# 30655.json is a valid JSON file.
# 32812.json is a valid JSON file.
# 28240.json is a valid JSON file.
# 28169.json is a valid JSON file.
# 30218.json is a valid JSON file.
# 26761.json is a valid JSON file.
# 30100.json is a valid JSON file.
# 33076.json is a valid JSON file.
# 33709.json is a valid JSON file.
# 32987.json is a valid JSON file.
# 27059.json is a valid JSON file.
# 26585.json is a valid JSON file.
# 29416.json is a valid JSON file.
# 28029.json is a valid JSON file.
# 29051.json is a valid JSON file.
# 32355.json is a valid JSON file.
# 28436.json is a valid JSON file.
# 31262.json is a valid JSON file.
# 27907.json is a valid JSON file.
# 30034.json is a valid JSON file.
# 27637.json is a valid JSON file.
# 27062.json is a valid JSON file.
# 27622.json is a valid JSON file.
# 31580.json is a valid JSON file.
# 29737.json is a valid JSON file.
# 32258.json is a valid JSON file.
# 38669.json is a valid JSON file.
# 32249.json is a valid JSON file.
# 33047.json is a valid JSON file.
# 28389.json is a valid JSON file.
# 32917.json is a valid JSON file.
# 30022.json is a valid JSON file.
# 26600.json is a valid JSON file.
# 32799.json is a valid JSON file.
# 34805.json is a valid JSON file.
# 33300.json is a valid JSON file.
# 32873.json is a valid JSON file.
# 27276.json is a valid JSON file.
# 26514.json is a valid JSON file.
# 27120.json is a valid JSON file.
# 31086.json is a valid JSON file.
# 29457.json is a valid JSON file.
# Invalid JSON detected: 29208.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/29208.json: Expecting property name enclosed in double quotes: line 108 column 9 (char 4755)
# 27313.json is a valid JSON file.
# 32927.json is a valid JSON file.
# 34406.json is a valid JSON file.
# 38812.json is a valid JSON file.
# 27455.json is a valid JSON file.
# 33605.json is a valid JSON file.
# 36864.json is a valid JSON file.
# 34851.json is a valid JSON file.
# 33896.json is a valid JSON file.
# 28916.json is a valid JSON file.
# 29426.json is a valid JSON file.
# 27072.json is a valid JSON file.
# 27006.json is a valid JSON file.
# 29839.json is a valid JSON file.
# 38935.json is a valid JSON file.
# 28070.json is a valid JSON file.
# 29780.json is a valid JSON file.
# 34709.json is a valid JSON file.
# 27295.json is a valid JSON file.
# 29341.json is a valid JSON file.
# 27439.json is a valid JSON file.
# 28292.json is a valid JSON file.
# 32245.json is a valid JSON file.
# 27464.json is a valid JSON file.
# 31385.json is a valid JSON file.
# 31919.json is a valid JSON file.
# 2820.json is a valid JSON file.
# 35543.json is a valid JSON file.
# 34217.json is a valid JSON file.
# 29710.json is a valid JSON file.
# 32112.json is a valid JSON file.
# 38456.json is a valid JSON file.
# 38725.json is a valid JSON file.
# 27778.json is a valid JSON file.
# 26742.json is a valid JSON file.
# 34224.json is a valid JSON file.
# 36853.json is a valid JSON file.
# 33880.json is a valid JSON file.
# 28566.json is a valid JSON file.
# 31298.json is a valid JSON file.
# 28505.json is a valid JSON file.
# 26891.json is a valid JSON file.
# 27287.json is a valid JSON file.
# 28553.json is a valid JSON file.
# 32572.json is a valid JSON file.
# 34485.json is a valid JSON file.
# 29295.json is a valid JSON file.
# 29925.json is a valid JSON file.
# 33473.json is a valid JSON file.
# 26759.json is a valid JSON file.
# 31724.json is a valid JSON file.
# 33745.json is a valid JSON file.
# 28509.json is a valid JSON file.
# 32216.json is a valid JSON file.
# 36766.json is a valid JSON file.
# 28216.json is a valid JSON file.
# 34966.json is a valid JSON file.
# 26885.json is a valid JSON file.
# 33939.json is a valid JSON file.
# 32915.json is a valid JSON file.
# 26835.json is a valid JSON file.
# 27932.json is a valid JSON file.
# 34872.json is a valid JSON file.
# 34562.json is a valid JSON file.
# 33171.json is a valid JSON file.
# 30533.json is a valid JSON file.
# 28600.json is a valid JSON file.
# 27797.json is a valid JSON file.
# 29566.json is a valid JSON file.
# 38893.json is a valid JSON file.
# 32432.json is a valid JSON file.
# 29989.json is a valid JSON file.
# 30505.json is a valid JSON file.
# 28677.json is a valid JSON file.
# 31269.json is a valid JSON file.
# 30278.json is a valid JSON file.
# Invalid JSON detected: 33737.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/33737.json: Expecting ',' delimiter: line 82 column 5 (char 2106)
# 27511.json is a valid JSON file.
# 28713.json is a valid JSON file.
# 32138.json is a valid JSON file.
# 26688.json is a valid JSON file.
# 34015.json is a valid JSON file.
# 28183.json is a valid JSON file.
# 27844.json is a valid JSON file.
# 32498.json is a valid JSON file.
# 34211.json is a valid JSON file.
# 27442.json is a valid JSON file.
# 27726.json is a valid JSON file.
# 30171.json is a valid JSON file.
# 33260.json is a valid JSON file.
# 29220.json is a valid JSON file.
# 33556.json is a valid JSON file.
# 33497.json is a valid JSON file.
# 28308.json is a valid JSON file.
# 32399.json is a valid JSON file.
# 27127.json is a valid JSON file.
# 28271.json is a valid JSON file.
# 26931.json is a valid JSON file.
# 38772.json is a valid JSON file.
# 26671.json is a valid JSON file.
# 32767.json is a valid JSON file.
# 27806.json is a valid JSON file.
# 30702.json is a valid JSON file.
# 32000.json is a valid JSON file.
# 30150.json is a valid JSON file.
# 28730.json is a valid JSON file.
# 29514.json is a valid JSON file.
# 26860.json is a valid JSON file.
# 31141.json is a valid JSON file.
# Invalid JSON detected: 28117.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/28117.json: Invalid control character at: line 25 column 145 (char 1127)
# 32620.json is a valid JSON file.
# 31394.json is a valid JSON file.
# 34191.json is a valid JSON file.
# 33083.json is a valid JSON file.
# 34597.json is a valid JSON file.
# 35663.json is a valid JSON file.
# 38684.json is a valid JSON file.
# 31659.json is a valid JSON file.
# 27678.json is a valid JSON file.
# 31369.json is a valid JSON file.
# 32346.json is a valid JSON file.
# 26912.json is a valid JSON file.
# 27742.json is a valid JSON file.
# 30495.json is a valid JSON file.
# 30256.json is a valid JSON file.
# 36767.json is a valid JSON file.
# 32338.json is a valid JSON file.
# 38728.json is a valid JSON file.
# 31712.json is a valid JSON file.
# 29805.json is a valid JSON file.
# 30812.json is a valid JSON file.
# 30275.json is a valid JSON file.
# 34972.json is a valid JSON file.
# 34243.json is a valid JSON file.
# 30795.json is a valid JSON file.
# 27100.json is a valid JSON file.
# 27338.json is a valid JSON file.
# 32240.json is a valid JSON file.
# 34830.json is a valid JSON file.
# 27815.json is a valid JSON file.
# 29922.json is a valid JSON file.
# 29142.json is a valid JSON file.
# 31683.json is a valid JSON file.
# 38995.json is a valid JSON file.
# 30945.json is a valid JSON file.
# 34154.json is a valid JSON file.
# 29474.json is a valid JSON file.
# 27685.json is a valid JSON file.
# 32521.json is a valid JSON file.
# 27561.json is a valid JSON file.
# 35609.json is a valid JSON file.
# 27700.json is a valid JSON file.
# 32904.json is a valid JSON file.
# 26808.json is a valid JSON file.
# 33716.json is a valid JSON file.
# 31049.json is a valid JSON file.
# 38951.json is a valid JSON file.
# 38987.json is a valid JSON file.
# Invalid JSON detected: 26960.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/26960.json: Expecting value: line 125 column 11 (char 4793)
# 33269.json is a valid JSON file.
# 34482.json is a valid JSON file.
# 27230.json is a valid JSON file.
# 38839.json is a valid JSON file.
# 2861.json is a valid JSON file.
# 31351.json is a valid JSON file.
# 29161.json is a valid JSON file.
# 30873.json is a valid JSON file.
# 31608.json is a valid JSON file.
# 27665.json is a valid JSON file.
# 34089.json is a valid JSON file.
# 38959.json is a valid JSON file.
# 34458.json is a valid JSON file.
# 38852.json is a valid JSON file.
# 28059.json is a valid JSON file.
# 33369.json is a valid JSON file.
# 33469.json is a valid JSON file.
# 31612.json is a valid JSON file.
# 2832.json is a valid JSON file.
# 36616.json is a valid JSON file.
# 29842.json is a valid JSON file.
# 29930.json is a valid JSON file.
# 38661.json is a valid JSON file.
# 30593.json is a valid JSON file.
# 29267.json is a valid JSON file.
# 32367.json is a valid JSON file.
# 33814.json is a valid JSON file.
# 30841.json is a valid JSON file.
# 27075.json is a valid JSON file.
# 32690.json is a valid JSON file.
# 26756.json is a valid JSON file.
# 26736.json is a valid JSON file.
# 27316.json is a valid JSON file.
# 30199.json is a valid JSON file.
# 27901.json is a valid JSON file.
# 32059.json is a valid JSON file.
# 32894.json is a valid JSON file.
# 26700.json is a valid JSON file.
# 35627.json is a valid JSON file.
# 34139.json is a valid JSON file.
# 27521.json is a valid JSON file.
# 34594.json is a valid JSON file.
# 30566.json is a valid JSON file.
# 34883.json is a valid JSON file.
# 34397.json is a valid JSON file.
# 28772.json is a valid JSON file.
# 28385.json is a valid JSON file.
# 34379.json is a valid JSON file.
# 29332.json is a valid JSON file.
# 26594.json is a valid JSON file.
# 30663.json is a valid JSON file.
# 34617.json is a valid JSON file.
# 28749.json is a valid JSON file.
# 38977.json is a valid JSON file.
# 27653.json is a valid JSON file.
# 26873.json is a valid JSON file.
# 32841.json is a valid JSON file.
# 26719.json is a valid JSON file.
# 36688.json is a valid JSON file.
# 33933.json is a valid JSON file.
# 33437.json is a valid JSON file.
# 28062.json is a valid JSON file.
# 32946.json is a valid JSON file.
# 29638.json is a valid JSON file.
# 31577.json is a valid JSON file.
# 28335.json is a valid JSON file.
# 29799.json is a valid JSON file.
# 33844.json is a valid JSON file.
# 33618.json is a valid JSON file.
# 29716.json is a valid JSON file.
# 28665.json is a valid JSON file.
# 38989.json is a valid JSON file.
# 31216.json is a valid JSON file.
# 35630.json is a valid JSON file.
# 28851.json is a valid JSON file.
# 28237.json is a valid JSON file.
# 34106.json is a valid JSON file.
# 31196.json is a valid JSON file.
# Invalid JSON detected: 32316.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/32316.json: Expecting ',' delimiter: line 66 column 5 (char 1388)
# 26896.json is a valid JSON file.
# 33454.json is a valid JSON file.
# 27794.json is a valid JSON file.
# 33511.json is a valid JSON file.
# Invalid JSON detected: 30552.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/30552.json: Expecting ',' delimiter: line 19 column 10 (char 1105)
# 27197.json is a valid JSON file.
# 32538.json is a valid JSON file.
# 28515.json is a valid JSON file.
# 35549.json is a valid JSON file.
# 28047.json is a valid JSON file.
# 30770.json is a valid JSON file.
# 38824.json is a valid JSON file.
# 33194.json is a valid JSON file.
# 29974.json is a valid JSON file.
# 31213.json is a valid JSON file.
# 38888.json is a valid JSON file.
# 33252.json is a valid JSON file.
# 31242.json is a valid JSON file.
# 31257.json is a valid JSON file.
# 33482.json is a valid JSON file.
# 34763.json is a valid JSON file.
# 29729.json is a valid JSON file.
# 31742.json is a valid JSON file.
# 27242.json is a valid JSON file.
# 30129.json is a valid JSON file.
# 26677.json is a valid JSON file.
# 28952.json is a valid JSON file.
# 28040.json is a valid JSON file.
# 35564.json is a valid JSON file.
# 34644.json is a valid JSON file.
# 29215.json is a valid JSON file.
# 33024.json is a valid JSON file.
# 32847.json is a valid JSON file.
# 32182.json is a valid JSON file.
# 38833.json is a valid JSON file.
# 28233.json is a valid JSON file.
# 33111.json is a valid JSON file.
# 27883.json is a valid JSON file.
# 27087.json is a valid JSON file.
# 30723.json is a valid JSON file.
# 33044.json is a valid JSON file.
# 35585.json is a valid JSON file.
# 32525.json is a valid JSON file.
# 30045.json is a valid JSON file.
# 26982.json is a valid JSON file.
# 30580.json is a valid JSON file.
# 34440.json is a valid JSON file.
# 33627.json is a valid JSON file.
# 30457.json is a valid JSON file.
# 30849.json is a valid JSON file.
# 32559.json is a valid JSON file.
# 29582.json is a valid JSON file.
# 30360.json is a valid JSON file.
# 32286.json is a valid JSON file.
# 28163.json is a valid JSON file.
# 32753.json is a valid JSON file.
# 33910.json is a valid JSON file.
# 29309.json is a valid JSON file.
# 30969.json is a valid JSON file.
# 35600.json is a valid JSON file.
# 34933.json is a valid JSON file.
# 29432.json is a valid JSON file.
# 34058.json is a valid JSON file.
# 36569.json is a valid JSON file.
# 26812.json is a valid JSON file.
# 29075.json is a valid JSON file.
# 36856.json is a valid JSON file.
# 28098.json is a valid JSON file.
# 30357.json is a valid JSON file.
# 38678.json is a valid JSON file.
# 34032.json is a valid JSON file.
# 31375.json is a valid JSON file.
# 34858.json is a valid JSON file.
# 34235.json is a valid JSON file.
# 27153.json is a valid JSON file.
# 30126.json is a valid JSON file.
# 30835.json is a valid JSON file.
# 33178.json is a valid JSON file.
# 31674.json is a valid JSON file.
# 33381.json is a valid JSON file.
# 31254.json is a valid JSON file.
# 28818.json is a valid JSON file.
# 28157.json is a valid JSON file.
# 31135.json is a valid JSON file.
# 26540.json is a valid JSON file.
# 32882.json is a valid JSON file.
# 30326.json is a valid JSON file.
# 38858.json is a valid JSON file.
# 29859.json is a valid JSON file.
# 27566.json is a valid JSON file.
# 27706.json is a valid JSON file.
# 30996.json is a valid JSON file.
# 28363.json is a valid JSON file.
# 34757.json is a valid JSON file.
# 31699.json is a valid JSON file.
# 30833.json is a valid JSON file.
# 28769.json is a valid JSON file.
# 33233.json is a valid JSON file.
# 32385.json is a valid JSON file.
# 27619.json is a valid JSON file.
# 29282.json is a valid JSON file.
# 30688.json is a valid JSON file.
# 27517.json is a valid JSON file.
# 31537.json is a valid JSON file.
# 29500.json is a valid JSON file.
# 32460.json is a valid JSON file.
# 34754.json is a valid JSON file.
# 29873.json is a valid JSON file.
# 32786.json is a valid JSON file.
# 26915.json is a valid JSON file.
# 30955.json is a valid JSON file.
# 31193.json is a valid JSON file.
# 30920.json is a valid JSON file.
# 27468.json is a valid JSON file.
# 31615.json is a valid JSON file.
# 27318.json is a valid JSON file.
# 33293.json is a valid JSON file.
# 30935.json is a valid JSON file.
# 29152.json is a valid JSON file.
# 38865.json is a valid JSON file.
# 26967.json is a valid JSON file.
# 30845.json is a valid JSON file.
# 26815.json is a valid JSON file.
# 28139.json is a valid JSON file.
# 27791.json is a valid JSON file.
# 34602.json is a valid JSON file.
# 35615.json is a valid JSON file.
# 34809.json is a valid JSON file.
# 32868.json is a valid JSON file.
# 30604.json is a valid JSON file.
# 27688.json is a valid JSON file.
# 30500.json is a valid JSON file.
# 29563.json is a valid JSON file.
# 31894.json is a valid JSON file.
# 34465.json is a valid JSON file.
# 30881.json is a valid JSON file.
# 28546.json is a valid JSON file.
# 29423.json is a valid JSON file.
# 30165.json is a valid JSON file.
# 31335.json is a valid JSON file.
# 34359.json is a valid JSON file.
# 30281.json is a valid JSON file.
# 28963.json is a valid JSON file.
# 33137.json is a valid JSON file.
# 31010.json is a valid JSON file.
# 30729.json is a valid JSON file.
# 26794.json is a valid JSON file.
# 26717.json is a valid JSON file.
# 30521.json is a valid JSON file.
# 29072.json is a valid JSON file.
# 28221.json is a valid JSON file.
# 30557.json is a valid JSON file.
# 32707.json is a valid JSON file.
# 29593.json is a valid JSON file.
# 28382.json is a valid JSON file.
# 28746.json is a valid JSON file.
# 29598.json is a valid JSON file.
# 38929.json is a valid JSON file.
# 30684.json is a valid JSON file.
# 32761.json is a valid JSON file.
# 27328.json is a valid JSON file.
# 30511.json is a valid JSON file.
# 29723.json is a valid JSON file.
# 32411.json is a valid JSON file.
# 29883.json is a valid JSON file.
# 27148.json is a valid JSON file.
# 30489.json is a valid JSON file.
# 29176.json is a valid JSON file.
# 32817.json is a valid JSON file.
# 31348.json is a valid JSON file.
# Invalid JSON detected: 35537.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/35537.json: Invalid control character at: line 11 column 363 (char 632)
# 29950.json is a valid JSON file.
# 33175.json is a valid JSON file.
# 27833.json is a valid JSON file.
# 27582.json is a valid JSON file.
# 26729.json is a valid JSON file.
# 29704.json is a valid JSON file.
# 29918.json is a valid JSON file.
# 28283.json is a valid JSON file.
# 28823.json is a valid JSON file.
# 28575.json is a valid JSON file.
# 34339.json is a valid JSON file.
# 32907.json is a valid JSON file.
# 30625.json is a valid JSON file.
# 30806.json is a valid JSON file.
# 33120.json is a valid JSON file.
# 32510.json is a valid JSON file.
# 27336.json is a valid JSON file.
# 32698.json is a valid JSON file.
# 29982.json is a valid JSON file.
# 34908.json is a valid JSON file.
# 30439.json is a valid JSON file.
# 26547.json is a valid JSON file.
# 34324.json is a valid JSON file.
# 31360.json is a valid JSON file.
# 34102.json is a valid JSON file.
# 34186.json is a valid JSON file.
# 36668.json is a valid JSON file.
# 32272.json is a valid JSON file.
# 31179.json is a valid JSON file.
# ...
# 33108.json is a valid JSON file.
# 28073.json is a valid JSON file.
# 31534.json is a valid JSON file.
# 31289.json is a valid JSON file.
# 26644.json is a valid JSON file.
# 27405.json is a valid JSON file.
# 27200.json is a valid JSON file.
# 29480.json is a valid JSON file.
# 27408.json is a valid JSON file.
# 29237.json is a valid JSON file.
# 31493.json is a valid JSON file.
# 35607.json is a valid JSON file.
# 26534.json is a valid JSON file.
# 30138.json is a valid JSON file.
# 30717.json is a valid JSON file.
# 35013.json is a valid JSON file.
# 27596.json is a valid JSON file.
# 2778.json is a valid JSON file.
# 29993.json is a valid JSON file.
# 2770.json is a valid JSON file.
# 28564.json is a valid JSON file.
# 29837.json is a valid JSON file.
# 32517.json is a valid JSON file.
# 27348.json is a valid JSON file.
# 27764.json is a valid JSON file.
# 30657.json is a valid JSON file.
# 34393.json is a valid JSON file.
# 28831.json is a valid JSON file.
# 31482.json is a valid JSON file.
# 38962.json is a valid JSON file.
# 28743.json is a valid JSON file.
# 32865.json is a valid JSON file.
# 30773.json is a valid JSON file.
# 30652.json is a valid JSON file.
# 26903.json is a valid JSON file.
# 33955.json is a valid JSON file.
# 34818.json is a valid JSON file.
# 29469.json is a valid JSON file.
# 30574.json is a valid JSON file.
# 34522.json is a valid JSON file.
# 26924.json is a valid JSON file.
# 33457.json is a valid JSON file.
# 26706.json is a valid JSON file.
# 36850.json is a valid JSON file.
# 36961.json is a valid JSON file.
# 28918.json is a valid JSON file.
# 32041.json is a valid JSON file.
# 32436.json is a valid JSON file.
# 29617.json is a valid JSON file.
# 36847.json is a valid JSON file.
# 32943.json is a valid JSON file.
# Invalid JSON detected: 27285.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/27285.json: Invalid control character at: line 137 column 12 (char 6201)
# 31292.json is a valid JSON file.
# 30085.json is a valid JSON file.
# 35531.json is a valid JSON file.
# 30147.json is a valid JSON file.
# 33152.json is a valid JSON file.
# 31222.json is a valid JSON file.
# 30751.json is a valid JSON file.
# 28524.json is a valid JSON file.
# 27165.json is a valid JSON file.
# 30388.json is a valid JSON file.
# 31605.json is a valid JSON file.
# 30007.json is a valid JSON file.
# 29113.json is a valid JSON file.
# 31505.json is a valid JSON file.
# 33560.json is a valid JSON file.
# 30818.json is a valid JSON file.
# 38740.json is a valid JSON file.
# 29326.json is a valid JSON file.
# 27703.json is a valid JSON file.
# 2840.json is a valid JSON file.
# 33960.json is a valid JSON file.
# 32070.json is a valid JSON file.
# 28966.json is a valid JSON file.
# 38737.json is a valid JSON file.
# 29518.json is a valid JSON file.
# 27818.json is a valid JSON file.
# 32610.json is a valid JSON file.
# 29726.json is a valid JSON file.
# 30629.json is a valid JSON file.
# 27267.json is a valid JSON file.
# 31596.json is a valid JSON file.
# 33565.json is a valid JSON file.
# 28402.json is a valid JSON file.
# 33805.json is a valid JSON file.
# 32476.json is a valid JSON file.
# 30003.json is a valid JSON file.
# 38862.json is a valid JSON file.
# 32939.json is a valid JSON file.
# 29626.json is a valid JSON file.
# 28420.json is a valid JSON file.
# 28633.json is a valid JSON file.
# 30909.json is a valid JSON file.
# 32819.json is a valid JSON file.
# 27872.json is a valid JSON file.
# 32692.json is a valid JSON file.
# 31909.json is a valid JSON file.
# 28296.json is a valid JSON file.
# 33494.json is a valid JSON file.
# 34794.json is a valid JSON file.
# 27569.json is a valid JSON file.
# 31976.json is a valid JSON file.
# 34098.json is a valid JSON file.
# 34287.json is a valid JSON file.
# 32834.json is a valid JSON file.
# 33401.json is a valid JSON file.
# 38912.json is a valid JSON file.
# 31305.json is a valid JSON file.
# 30894.json is a valid JSON file.
# 30809.json is a valid JSON file.
# 35657.json is a valid JSON file.
# 27904.json is a valid JSON file.
# 29604.json is a valid JSON file.
# 38652.json is a valid JSON file.
# 33860.json is a valid JSON file.
# 31520.json is a valid JSON file.
# 28944.json is a valid JSON file.
# 28201.json is a valid JSON file.
# 34979.json is a valid JSON file.
# 34206.json is a valid JSON file.
# 33574.json is a valid JSON file.
# 29386.json is a valid JSON file.
# 29487.json is a valid JSON file.
# 26662.json is a valid JSON file.
# 33732.json is a valid JSON file.
# 34429.json is a valid JSON file.
# 27898.json is a valid JSON file.
# 34437.json is a valid JSON file.
# 33825.json is a valid JSON file.
# 26900.json is a valid JSON file.
# 30899.json is a valid JSON file.
# 28091.json is a valid JSON file.
# 32618.json is a valid JSON file.
# 27111.json is a valid JSON file.
# 27959.json is a valid JSON file.
# 27714.json is a valid JSON file.
# 27254.json is a valid JSON file.
# 28537.json is a valid JSON file.
# 30980.json is a valid JSON file.
# 29493.json is a valid JSON file.
# 2793.json is a valid JSON file.
# 28671.json is a valid JSON file.
# 36887.json is a valid JSON file.
# 38850.json is a valid JSON file.
# 33996.json is a valid JSON file.
# 29825.json is a valid JSON file.
# 31132.json is a valid JSON file.
# 31228.json is a valid JSON file.
# 33019.json is a valid JSON file.
# 34355.json is a valid JSON file.
# 34747.json is a valid JSON file.
# 29822.json is a valid JSON file.
# 34812.json is a valid JSON file.
# 31672.json is a valid JSON file.
# 31693.json is a valid JSON file.
# 28998.json is a valid JSON file.
# 2815.json is a valid JSON file.
# 30577.json is a valid JSON file.
# 33589.json is a valid JSON file.
# 38915.json is a valid JSON file.
# 32897.json is a valid JSON file.
# 33621.json is a valid JSON file.
# 2782.json is a valid JSON file.
# 32683.json is a valid JSON file.
# 27065.json is a valid JSON file.
# 27341.json is a valid JSON file.
# 34246.json is a valid JSON file.
# 26979.json is a valid JSON file.
# 29941.json is a valid JSON file.
# 28596.json is a valid JSON file.
# 27892.json is a valid JSON file.
# 34993.json is a valid JSON file.
# 32403.json is a valid JSON file.
# 30943.json is a valid JSON file.
# 31573.json is a valid JSON file.
# 31647.json is a valid JSON file.
# 32680.json is a valid JSON file.
# 31023.json is a valid JSON file.
# 30259.json is a valid JSON file.
# 31379.json is a valid JSON file.
# 34903.json is a valid JSON file.
# 32242.json is a valid JSON file.
# 38871.json is a valid JSON file.
# 29065.json is a valid JSON file.
# 29877.json is a valid JSON file.
# 31591.json is a valid JSON file.
# 27012.json is a valid JSON file.
# 30079.json is a valid JSON file.
# 27298.json is a valid JSON file.
# 28572.json is a valid JSON file.
# 32602.json is a valid JSON file.
# 38784.json is a valid JSON file.
# 31496.json is a valid JSON file.
# 32593.json is a valid JSON file.
# 29335.json is a valid JSON file.
# 32372.json is a valid JSON file.
# 30987.json is a valid JSON file.
# 34157.json is a valid JSON file.
# 26666.json is a valid JSON file.
# 30747.json is a valid JSON file.
# 29732.json is a valid JSON file.
# 38711.json is a valid JSON file.
# 31462.json is a valid JSON file.
# 38649.json is a valid JSON file.
# 32653.json is a valid JSON file.
# 31936.json is a valid JSON file.
# 26650.json is a valid JSON file.
# 26871.json is a valid JSON file.
# 30787.json is a valid JSON file.
# 34656.json is a valid JSON file.
# 38818.json is a valid JSON file.
# 33360.json is a valid JSON file.
# 28398.json is a valid JSON file.
# 30642.json is a valid JSON file.
# 29938.json is a valid JSON file.
# 33348.json is a valid JSON file.
# 30714.json is a valid JSON file.
# 29179.json is a valid JSON file.
# 26523.json is a valid JSON file.
# 29158.json is a valid JSON file.
# 31904.json is a valid JSON file.
# 30870.json is a valid JSON file.
# 38761.json is a valid JSON file.
# 32008.json is a valid JSON file.
# 34024.json is a valid JSON file.
# 32501.json is a valid JSON file.
# 34117.json is a valid JSON file.
# 31091.json is a valid JSON file.
# 33202.json is a valid JSON file.
# 38674.json is a valid JSON file.
# 30639.json is a valid JSON file.
# 35582.json is a valid JSON file.
# 32160.json is a valid JSON file.
# 29351.json is a valid JSON file.
# 29769.json is a valid JSON file.
# 27478.json is a valid JSON file.
# 30186.json is a valid JSON file.
# 34791.json is a valid JSON file.
# 32442.json is a valid JSON file.
# 31345.json is a valid JSON file.
# 31734.json is a valid JSON file.
# 33517.json is a valid JSON file.
# 32615.json is a valid JSON file.
# 34719.json is a valid JSON file.
# 34258.json is a valid JSON file.
# 31523.json is a valid JSON file.
# 26550.json is a valid JSON file.
# 30632.json is a valid JSON file.
# 33442.json is a valid JSON file.
# 28145.json is a valid JSON file.
# 34530.json is a valid JSON file.
# 29695.json is a valid JSON file.
# 29490.json is a valid JSON file.
# 27378.json is a valid JSON file.
# 31357.json is a valid JSON file.
# 30699.json is a valid JSON file.
# 30992.json is a valid JSON file.
# 35602.json is a valid JSON file.
# 28134.json is a valid JSON file.
# 30940.json is a valid JSON file.
# 28921.json is a valid JSON file.
# 34861.json is a valid JSON file.
# 29344.json is a valid JSON file.
# 2855.json is a valid JSON file.
# 38992.json is a valid JSON file.
# 34375.json is a valid JSON file.
# 27090.json is a valid JSON file.
# 31177.json is a valid JSON file.
# 33476.json is a valid JSON file.
# 34963.json is a valid JSON file.
# 29698.json is a valid JSON file.
# 27770.json is a valid JSON file.
# 28414.json is a valid JSON file.
# 26941.json is a valid JSON file.
# 32919.json is a valid JSON file.
# 32981.json is a valid JSON file.
# 34686.json is a valid JSON file.
# 28494.json is a valid JSON file.
# 31662.json is a valid JSON file.
# 31471.json is a valid JSON file.
# 33823.json is a valid JSON file.
# 33288.json is a valid JSON file.
# 29863.json is a valid JSON file.
# 33257.json is a valid JSON file.
# 33792.json is a valid JSON file.
# 32696.json is a valid JSON file.
# 34943.json is a valid JSON file.
# 32542.json is a valid JSON file.
# 32567.json is a valid JSON file.
# 38938.json is a valid JSON file.
# 32976.json is a valid JSON file.
# 33740.json is a valid JSON file.
# 26641.json is a valid JSON file.
# 38980.json is a valid JSON file.
# 29505.json is a valid JSON file.
# 34313.json is a valid JSON file.
# 38719.json is a valid JSON file.
# 28246.json is a valid JSON file.
# 32154.json is a valid JSON file.
# 38769.json is a valid JSON file.
# 38806.json is a valid JSON file.
# 31479.json is a valid JSON file.
# 27030.json is a valid JSON file.
# 30028.json is a valid JSON file.
# 27657.json is a valid JSON file.
# 27236.json is a valid JSON file.
# 30666.json is a valid JSON file.
# 33139.json is a valid JSON file.
# 29483.json is a valid JSON file.
# 31499.json is a valid JSON file.
# 34142.json is a valid JSON file.
# 29740.json is a valid JSON file.
# 33704.json is a valid JSON file.
# 30014.json is a valid JSON file.
# 34877.json is a valid JSON file.
# 31003.json is a valid JSON file.
# 27124.json is a valid JSON file.
# 33595.json is a valid JSON file.
# 31980.json is a valid JSON file.
# 29202.json is a valid JSON file.
# 38827.json is a valid JSON file.
# 34897.json is a valid JSON file.
# 31060.json is a valid JSON file.
# 32650.json is a valid JSON file.
# 29817.json is a valid JSON file.
# 31153.json is a valid JSON file.
# 34426.json is a valid JSON file.
# 28812.json is a valid JSON file.
# 29962.json is a valid JSON file.
# 32932.json is a valid JSON file.
# 30478.json is a valid JSON file.
# 33303.json is a valid JSON file.
# 28171.json is a valid JSON file.
# 34696.json is a valid JSON file.
# 30527.json is a valid JSON file.
# 34744.json is a valid JSON file.
# 30607.json is a valid JSON file.
# 32999.json is a valid JSON file.
# 28469.json is a valid JSON file.
# Invalid JSON detected: 30912.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/30912.json: Invalid \escape: line 11 column 137 (char 390)
# 33247.json is a valid JSON file.
# 26525.json is a valid JSON file.
# Invalid JSON detected: 34364.json, attempting to fix...
# Error fixing leaflet_jsons_2017_2019/34364.json: Expecting ',' delimiter: line 78 column 68 (char 5655)
# 26725.json is a valid JSON file.
# 30270.json is a valid JSON file.
# 27672.json is a valid JSON file.
# 33206.json is a valid JSON file.
# 28341.json is a valid JSON file.
# 34556.json is a valid JSON file.
# 30244.json is a valid JSON file.
# 33189.json is a valid JSON file.
# 31308.json is a valid JSON file.
# 29516.json is a valid JSON file.
# 30342.json is a valid JSON file.
# 29288.json is a valid JSON file.
# 28701.json is a valid JSON file.
# 35651.json is a valid JSON file.
# 31182.json is a valid JSON file.
# 29527.json is a valid JSON file.
# 27445.json is a valid JSON file.
# 28343.json is a valid JSON file.
# 35612.json is a valid JSON file.
# 30211.json is a valid JSON file.
# 28854.json is a valid JSON file.
# 34009.json is a valid JSON file.
# 26988.json is a valid JSON file.
# 27142.json is a valid JSON file.
# 29707.json is a valid JSON file.
# 28889.json is a valid JSON file.
# 28126.json is a valid JSON file.
# 26888.json is a valid JSON file.
# 32790.json is a valid JSON file.
# 31540.json is a valid JSON file.
# 27748.json is a valid JSON file.
# 26964.json is a valid JSON file.
# 28924.json is a valid JSON file.
# 31625.json is a valid JSON file.
# 28908.json is a valid JSON file.
# 27949.json is a valid JSON file.
# 29232.json is a valid JSON file.
# 28394.json is a valid JSON file.
# 31080.json is a valid JSON file.
# 2843.json is a valid JSON file.
# 32260.json is a valid JSON file.
# 33114.json is a valid JSON file.
# 28939.json is a valid JSON file.
# 34408.json is a valid JSON file.
# 29831.json is a valid JSON file.
# 26656.json is a valid JSON file.
# 29701.json is a valid JSON file.
# 30906.json is a valid JSON file.
# 30048.json is a valid JSON file.
# 27495.json is a valid JSON file.
# 27781.json is a valid JSON file.
# 33485.json is a valid JSON file.
# 28859.json is a valid JSON file.
# 34668.json is a valid JSON file.
# 38955.json is a valid JSON file.
# 28132.json is a valid JSON file.
# 27925.json is a valid JSON file.
# 27248.json is a valid JSON file.
# 38815.json is a valid JSON file.
# 27755.json is a valid JSON file.
# 32484.json is a valid JSON file.
# 30382.json is a valid JSON file.
# 29985.json is a valid JSON file.
# 30962.json is a valid JSON file.
# 38855.json is a valid JSON file.
# 30539.json is a valid JSON file.
# 29534.json is a valid JSON file.
# 35020.json is a valid JSON file.
# 30306.json is a valid JSON file.
# 32234.json is a valid JSON file.
# 2786.json is a valid JSON file.
# 38880.json is a valid JSON file.
# 32102.json is a valid JSON file.
# 34462.json is a valid JSON file.
# 28501.json is a valid JSON file.
# 28698.json is a valid JSON file.
# 28337.json is a valid JSON file.
# 27218.json is a valid JSON file.
# 33150.json is a valid JSON file.
# 30447.json is a valid JSON file.
# 29523.json is a valid JSON file.
# 30563.json is a valid JSON file.
# 33351.json is a valid JSON file.
# 36859.json is a valid JSON file.
# 33414.json is a valid JSON file.
# 32623.json is a valid JSON file.
# 34782.json is a valid JSON file.
# 32445.json is a valid JSON file.
# 28256.json is a valid JSON file.
# 33354.json is a valid JSON file.
# 38658.json is a valid JSON file.
# 32327.json is a valid JSON file.
# 30300.json is a valid JSON file.
# 29320.json is a valid JSON file.
# 30926.json is a valid JSON file.
# 31956.json is a valid JSON file.
# 32597.json is a valid JSON file.
# 2837.json is a valid JSON file.
# 30134.json is a valid JSON file.
# 31185.json is a valid JSON file.
# 31707.json is a valid JSON file.
# 32288.json is a valid JSON file.
# 33491.json is a valid JSON file.
# 38082.json is a valid JSON file.
# 33244.json is a valid JSON file.
# 27180.json is a valid JSON file.
# 31721.json is a valid JSON file.
# 34220.json is a valid JSON file.
# 31488.json is a valid JSON file.
# 31121.json is a valid JSON file.
# 27821.json is a valid JSON file.
# 34196.json is a valid JSON file.
# 32471.json is a valid JSON file.
# 30838.json is a valid JSON file.
# 31071.json is a valid JSON file.
# 34546.json is a valid JSON file.
# 29530.json is a valid JSON file.
# 31118.json is a valid JSON file.
# 30042.json is a valid JSON file.
# 26722.json is a valid JSON file.
# 29007.json is a valid JSON file.
# 32207.json is a valid JSON file.
# 2828.json is a valid JSON file.
# 33409.json is a valid JSON file.
# 31944.json is a valid JSON file.
# 33068.json is a valid JSON file.
# 34214.json is a valid JSON file.
# 28355.json is a valid JSON file.
# 30738.json is a valid JSON file.

# %%
import json
import os
import shutil

def check_json_structure(file_path):
    """Check if JSON file adheres to the specified structure."""
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON in {file_path}: {e}")
        return False  # Indicating that this file does not adhere due to a JSON error

    # Define the expected structure
    expected_structure = {
        "leaflet": {
            "candidateName": str,
            "candidateGender": str,
            "constituency": str,
            "politicalParty": str,
            "electionDate": str,
            "messages": [
                {
                    "title": str,
                    "content": str
                }
            ],
            "keyPolicies": [
                {
                    "policyTitle": str,
                    "policyDescription": str
                }
            ],
            "mentions": {
                "candidate": str,
                "otherPartyLeaderCandidate": str,
                "partyLeader": str,
                "tacticalSituation": str
            },
            "issues": {
                "brexitEurope": str,
                "defence": str,
                "economy": str,
                "education": str,
                "environment": str,
                "governance": str,
                "government": str,
                "health": str,
                "immigration": str,
                "labourEmployment": str,
                "lawCrime": str,
                "transport": str,
                "socialWelfare": str,
                "community": [
                    {
                        "content": str,
                        "yimbyNimby": str
                    }
                ]
            },
            "personalStatement": str,
            "politicalExperience": [
                {
                    "role": str,
                    "duration": str,
                    "achievements": str
                }
            ],
            "contactInformation": {
                "address": str,
                "phone": str,
                "email": str,
                "website": str,
                "socialMedia": {
                    "facebook": str,
                    "twitter": str,
                    "instagram": str,
                    "linkedin": str
                }
            },
            "endorsements": [
                {
                    "endorser": str,
                    "endorsement": str
                }
            ],
            "quotes": [
                {
                    "text": str,
                    "source": str,
                    "date": str
                }
            ],
            "campaignMaterial": {
                "images": [
                    {
                        "caption": str
                    }
                ]
            },
            "additionalNotes": str,
            "analysis": {
                "statementAnalysis": {
                    "quantitative": {
                        "count": int,
                        "examples": [str]
                    },
                    "qualitative": {
                        "count": int,
                        "examples": [str]
                    }
                },
                "photoAnalysis": {
                    "localPlaces": int,
                    "people": int,
                    "candidateAlone": int,
                    "candidateWithOthers": int
                },
                "issueFocus": {
                    "local": {
                        "count": int,
                        "examples": [str]
                    },
                    "national": {
                        "count": int,
                        "examples": [str]
                    }
                },
                "personalStories": [
                    {
                        "story": str,
                        "issueRelated": str
                    }
                ],
                "endorsementsUsed": {
                    "count": int,
                    "examples": [str]
                },
                "negativeMessaging": {
                    "localIssues": {
                        "count": int,
                        "examples": [str]
                    },
                    "nationalIssues": {
                        "count": int,
                        "examples": [str]
                    },
                    "leaderOfOpponentsParty": {
                        "count": int,
                        "examples": [str]
                    },
                    "oppositeCandidateNoName": {
                        "count": int,
                        "examples": [str]
                    },
                    "oppositeCandidateWithName": {
                        "count": int,
                        "examples": [str]
                    }
                },
                "nonPolicyAttributes": {
                    "localness": str,
                    "employment": str,
                    "education": str,
                    "family": str
                },
                "localCandidate": {
                    "isLocal": bool,
                    "examples": [str]
                }
            }
        }
    }

    def check_structure(data, structure):
        if type(data) is list:
            if type(structure) is list and len(structure) > 0:
                return all(check_structure(item, structure[0]) for item in data)
            else:
                return False
        elif type(data) is dict:
            if type(structure) is dict:
                for key, value in structure.items():
                    if key not in data or not check_structure(data[key], value):
                        return False
                return True
            else:
                return False
        else:
            return type(data) == structure

    return check_structure(data, expected_structure)

def process_directory_for_structure(directory_path):
    faulty_dir = os.path.join(directory_path, "faulty")
    if not os.path.exists(faulty_dir):
        os.makedirs(faulty_dir)

    num_bad = 0
    for filename in os.listdir(directory_path):
        if filename.endswith('.json'):
            file_path = os.path.join(directory_path, filename)
            if not check_json_structure(file_path):
                print(f"{filename} does not adhere to the specified format.")
                faulty_file_path = os.path.join(faulty_dir, filename)
                shutil.move(file_path, faulty_file_path)  # Move the file to the "faulty" directory
                num_bad += 1
    print(f"Moved {num_bad} files to the faulty directory.")

# Replace 'your_directory_path' with the path to your directory containing JSON files
directory_path = 'leaflet_jsons_2017_2019'
process_directory_for_structure(directory_path)
# Out:
# 28267.json does not adhere to the specified format.
# 33130.json does not adhere to the specified format.
# 32143.json does not adhere to the specified format.
# 33856.json does not adhere to the specified format.
# 30202.json does not adhere to the specified format.
# 34526.json does not adhere to the specified format.
# 27056.json does not adhere to the specified format.
# 29777.json does not adhere to the specified format.
# 28875.json does not adhere to the specified format.
# 27841.json does not adhere to the specified format.
# 32529.json does not adhere to the specified format.
# 27191.json does not adhere to the specified format.
# 29188.json does not adhere to the specified format.
# 28311.json does not adhere to the specified format.
# 34500.json does not adhere to the specified format.
# 38799.json does not adhere to the specified format.
# 27245.json does not adhere to the specified format.
# 27257.json does not adhere to the specified format.
# 30596.json does not adhere to the specified format.
# 30072.json does not adhere to the specified format.
# 28990.json does not adhere to the specified format.
# 35604.json does not adhere to the specified format.
# 31129.json does not adhere to the specified format.
# 30757.json does not adhere to the specified format.
# 32876.json does not adhere to the specified format.
# 28782.json does not adhere to the specified format.
# 28705.json does not adhere to the specified format.
# 29245.json does not adhere to the specified format.
# 28405.json does not adhere to the specified format.
# 26751.json does not adhere to the specified format.
# 31927.json does not adhere to the specified format.
# 27027.json does not adhere to the specified format.
# 33666.json does not adhere to the specified format.
# 30162.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/33811.json: Expecting value: line 1 column 1 (char 0)
# 33811.json does not adhere to the specified format.
# 26588.json does not adhere to the specified format.
# 28904.json does not adhere to the specified format.
# 35532.json does not adhere to the specified format.
# 27394.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/29027.json: Expecting value: line 1 column 1 (char 0)
# 29027.json does not adhere to the specified format.
# 34740.json does not adhere to the specified format.
# 30062.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/33036.json: Expecting value: line 1 column 1 (char 0)
# 33036.json does not adhere to the specified format.
# 27321.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/34240.json: Expecting value: line 1 column 1 (char 0)
# 34240.json does not adhere to the specified format.
# 29757.json does not adhere to the specified format.
# 28683.json does not adhere to the specified format.
# 33239.json does not adhere to the specified format.
# 32549.json does not adhere to the specified format.
# 30451.json does not adhere to the specified format.
# 34148.json does not adhere to the specified format.
# 26694.json does not adhere to the specified format.
# 33124.json does not adhere to the specified format.
# 33608.json does not adhere to the specified format.
# 27578.json does not adhere to the specified format.
# 30223.json does not adhere to the specified format.
# 34085.json does not adhere to the specified format.
# 35534.json does not adhere to the specified format.
# 31317.json does not adhere to the specified format.
# 33391.json does not adhere to the specified format.
# 30917.json does not adhere to the specified format.
# 28756.json does not adhere to the specified format.
# 30422.json does not adhere to the specified format.
# 34290.json does not adhere to the specified format.
# 28709.json does not adhere to the specified format.
# 27157.json does not adhere to the specified format.
# 32466.json does not adhere to the specified format.
# 30999.json does not adhere to the specified format.
# 33061.json does not adhere to the specified format.
# 33985.json does not adhere to the specified format.
# 34151.json does not adhere to the specified format.
# 34886.json does not adhere to the specified format.
# 34584.json does not adhere to the specified format.
# 30379.json does not adhere to the specified format.
# 26647.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/34675.json: Expecting ',' delimiter: line 25 column 5 (char 522)
# 34675.json does not adhere to the specified format.
# 32283.json does not adhere to the specified format.
# 33721.json does not adhere to the specified format.
# 27170.json does not adhere to the specified format.
# 27211.json does not adhere to the specified format.
# 33212.json does not adhere to the specified format.
# 28803.json does not adhere to the specified format.
# 32825.json does not adhere to the specified format.
# 30571.json does not adhere to the specified format.
# 34869.json does not adhere to the specified format.
# 30363.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/28053.json: Expecting value: line 1 column 1 (char 0)
# 28053.json does not adhere to the specified format.
# 27767.json does not adhere to the specified format.
# 28251.json does not adhere to the specified format.
# 29766.json does not adhere to the specified format.
# 34581.json does not adhere to the specified format.
# 33514.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/32783.json: Expecting value: line 1 column 1 (char 0)
# 32783.json does not adhere to the specified format.
# 29856.json does not adhere to the specified format.
# 27176.json does not adhere to the specified format.
# 30320.json does not adhere to the specified format.
# 29106.json does not adhere to the specified format.
# 32987.json does not adhere to the specified format.
# 26600.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/29208.json: Expecting value: line 1 column 1 (char 0)
# 29208.json does not adhere to the specified format.
# 32927.json does not adhere to the specified format.
# 38812.json does not adhere to the specified format.
# 29839.json does not adhere to the specified format.
# 28292.json does not adhere to the specified format.
# 27464.json does not adhere to the specified format.
# 29925.json does not adhere to the specified format.
# 28509.json does not adhere to the specified format.
# 32216.json does not adhere to the specified format.
# 28216.json does not adhere to the specified format.
# 34966.json does not adhere to the specified format.
# 26835.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/33737.json: Expecting value: line 1 column 1 (char 0)
# 33737.json does not adhere to the specified format.
# 32399.json does not adhere to the specified format.
# 28271.json does not adhere to the specified format.
# 28730.json does not adhere to the specified format.
# 31141.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/28117.json: Expecting value: line 1 column 1 (char 0)
# 28117.json does not adhere to the specified format.
# 26912.json does not adhere to the specified format.
# 32338.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/26960.json: Expecting value: line 1 column 1 (char 0)
# 26960.json does not adhere to the specified format.
# 33369.json does not adhere to the specified format.
# 31612.json does not adhere to the specified format.
# 33618.json does not adhere to the specified format.
# 29716.json does not adhere to the specified format.
# 28665.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/32316.json: Expecting value: line 1 column 1 (char 0)
# 32316.json does not adhere to the specified format.
# 27794.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/30552.json: Expecting value: line 1 column 1 (char 0)
# 30552.json does not adhere to the specified format.
# 31242.json does not adhere to the specified format.
# 32847.json does not adhere to the specified format.
# 32559.json does not adhere to the specified format.
# 34235.json does not adhere to the specified format.
# 26540.json does not adhere to the specified format.
# 30326.json does not adhere to the specified format.
# 27566.json does not adhere to the specified format.
# 29282.json does not adhere to the specified format.
# 26915.json does not adhere to the specified format.
# 35615.json does not adhere to the specified format.
# 28382.json does not adhere to the specified format.
# 29598.json does not adhere to the specified format.
# 27328.json does not adhere to the specified format.
# 30511.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/35537.json: Expecting value: line 1 column 1 (char 0)
# 35537.json does not adhere to the specified format.
# 29918.json does not adhere to the specified format.
# 32698.json does not adhere to the specified format.
# 30439.json does not adhere to the specified format.
# 34186.json does not adhere to the specified format.
# 33968.json does not adhere to the specified format.
# 34121.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/32254.json: Expecting value: line 1 column 1 (char 0)
# 32254.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/32885.json: Expecting value: line 1 column 1 (char 0)
# 32885.json does not adhere to the specified format.
# 31100.json does not adhere to the specified format.
# 34620.json does not adhere to the specified format.
# 28280.json does not adhere to the specified format.
# 33330.json does not adhere to the specified format.
# 27009.json does not adhere to the specified format.
# 32822.json does not adhere to the specified format.
# 27043.json does not adhere to the specified format.
# 32209.json does not adhere to the specified format.
# 38749.json does not adhere to the specified format.
# 28225.json does not adhere to the specified format.
# 27644.json does not adhere to the specified format.
# 33297.json does not adhere to the specified format.
# 30903.json does not adhere to the specified format.
# 29476.json does not adhere to the specified format.
# 30052.json does not adhere to the specified format.
# 33404.json does not adhere to the specified format.
# 28651.json does not adhere to the specified format.
# 27546.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/28026.json: Expecting value: line 1 column 1 (char 0)
# 28026.json does not adhere to the specified format.
# 30434.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/32205.json: Expecting value: line 1 column 1 (char 0)
# 32205.json does not adhere to the specified format.
# 29658.json does not adhere to the specified format.
# 29542.json does not adhere to the specified format.
# 29790.json does not adhere to the specified format.
# 33936.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/34900.json: Expecting value: line 1 column 1 (char 0)
# 34900.json does not adhere to the specified format.
# 33383.json does not adhere to the specified format.
# 32266.json does not adhere to the specified format.
# 30619.json does not adhere to the specified format.
# 27800.json does not adhere to the specified format.
# 34320.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/35588.json: Expecting value: line 1 column 1 (char 0)
# 35588.json does not adhere to the specified format.
# 27739.json does not adhere to the specified format.
# 2803.json does not adhere to the specified format.
# 31035.json does not adhere to the specified format.
# 31163.json does not adhere to the specified format.
# 30188.json does not adhere to the specified format.
# 29868.json does not adhere to the specified format.
# 35642.json does not adhere to the specified format.
# 28299.json does not adhere to the specified format.
# 30854.json does not adhere to the specified format.
# 34145.json does not adhere to the specified format.
# 29623.json does not adhere to the specified format.
# 33777.json does not adhere to the specified format.
# 29365.json does not adhere to the specified format.
# 38693.json does not adhere to the specified format.
# 27183.json does not adhere to the specified format.
# 33729.json does not adhere to the specified format.
# 34535.json does not adhere to the specified format.
# 33636.json does not adhere to the specified format.
# 30767.json does not adhere to the specified format.
# 30560.json does not adhere to the specified format.
# 32912.json does not adhere to the specified format.
# 28472.json does not adhere to the specified format.
# 30444.json does not adhere to the specified format.
# 31102.json does not adhere to the specified format.
# 30518.json does not adhere to the specified format.
# 31582.json does not adhere to the specified format.
# 27918.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/34037.json: Expecting value: line 1 column 1 (char 0)
# 34037.json does not adhere to the specified format.
# 33108.json does not adhere to the specified format.
# 29237.json does not adhere to the specified format.
# 30717.json does not adhere to the specified format.
# 32517.json does not adhere to the specified format.
# 27764.json does not adhere to the specified format.
# 34818.json does not adhere to the specified format.
# 29469.json does not adhere to the specified format.
# 36847.json does not adhere to the specified format.
# 32943.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/27285.json: Expecting value: line 1 column 1 (char 0)
# 27285.json does not adhere to the specified format.
# 30388.json does not adhere to the specified format.
# 29518.json does not adhere to the specified format.
# 30003.json does not adhere to the specified format.
# 32939.json does not adhere to the specified format.
# 34206.json does not adhere to the specified format.
# 27959.json does not adhere to the specified format.
# 30980.json does not adhere to the specified format.
# 36887.json does not adhere to the specified format.
# 31672.json does not adhere to the specified format.
# 31591.json does not adhere to the specified format.
# 34157.json does not adhere to the specified format.
# 34656.json does not adhere to the specified format.
# 28398.json does not adhere to the specified format.
# 31904.json does not adhere to the specified format.
# 31091.json does not adhere to the specified format.
# 30639.json does not adhere to the specified format.
# 30186.json does not adhere to the specified format.
# 34530.json does not adhere to the specified format.
# 29490.json does not adhere to the specified format.
# 28414.json does not adhere to the specified format.
# 34686.json does not adhere to the specified format.
# 26641.json does not adhere to the specified format.
# 38719.json does not adhere to the specified format.
# 31060.json does not adhere to the specified format.
# 28812.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/30912.json: Expecting value: line 1 column 1 (char 0)
# 30912.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons_2017_2019/34364.json: Expecting value: line 1 column 1 (char 0)
# 34364.json does not adhere to the specified format.
# 30244.json does not adhere to the specified format.
# 29527.json does not adhere to the specified format.
# 26656.json does not adhere to the specified format.
# 27925.json does not adhere to the specified format.
# 2786.json does not adhere to the specified format.
# 28337.json does not adhere to the specified format.
# 29523.json does not adhere to the specified format.
# 29320.json does not adhere to the specified format.
# 31071.json does not adhere to the specified format.
# 28355.json does not adhere to the specified format.
# Moved 258 files to the faulty directory.
